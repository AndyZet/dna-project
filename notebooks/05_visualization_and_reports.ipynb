# %% [markdown]
# # Visualization and Reports
#
# This notebook generates visualizations and reports:
# - Phylogenetic trees
# - Migration maps
# - Family trees
# - Hypothesis verification reports

# %%
import sys
import os
sys.path.insert(0, os.path.join('..', 'src'))

import matplotlib.pyplot as plt
import seaborn as sns
from visualization.phylogenetic_trees import generate_haplogroup_tree
from visualization.migration_maps import create_migration_map
from visualization.family_trees import create_interactive_family_tree
from visualization.report_generator import generate_hypothesis_report
