# %% [markdown]
# # Ancient DNA Matching
#
# This notebook matches your DNA to ancient DNA samples:
# - Bodzia cemetery samples
# - Kievan Rus' populations
# - Admixture analysis

# %%
import sys
import os
sys.path.insert(0, os.path.join('..', 'src'))

import pandas as pd
from ancient_dna.bodzia_matcher import match_bodzia_samples
from ancient_dna.kievan_rus_analysis import analyze_kievan_rus_connections
from ancient_dna.admixture_estimator import estimate_admixture
