# %% [markdown]
# # Y-DNA Haplogroup Analysis
#
# This notebook analyzes Y-DNA haplogroup data, including:
# - Parsing ISOGG tree
# - Analyzing SNP data
# - Calculating TMRCA
# - Y-STR comparisons

# %%
import sys
import os
sys.path.insert(0, os.path.join('..', 'src'))

import pandas as pd
import numpy as np
from y_dna.haplogroup_parser import parse_isogg_tree, find_haplogroup
from y_dna.snp_analyzer import analyze_snps
from y_dna.tmrca_calculator import calculate_tmrca

# %% [markdown]
# ## Load ISOGG Y-DNA Tree

# %%
# Parse ISOGG tree
isogg_tree = parse_isogg_tree('../data/reference/isogg_y_tree.csv')
print(f"Loaded {len(isogg_tree)} haplogroup entries")
