# %% [markdown]
# # Migration Analysis
#
# This notebook analyzes family migration patterns:
# - Geographic distribution
# - Migration routes
# - Timeline analysis

# %%
import sys
import os
sys.path.insert(0, os.path.join('..', 'src'))

import pandas as pd
from genealogical.migration_analyzer import analyze_migrations, create_migration_map
