# %% [markdown]
# # Genealogical Tree Validation
#
# This notebook validates family tree data:
# - Parse GEDCOM files
# - Validate lineages
# - Find common ancestors

# %%
import sys
import os
sys.path.insert(0, os.path.join('..', 'src'))

from genealogical.gedcom_parser import parse_family_tree
from genealogical.family_tree_validator import validate_lineage, find_common_ancestors
